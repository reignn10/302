# %% [markdown]
# <a href="https://colab.research.google.com/github/reignn10/302/blob/main/Assesment_task_2_Bayani.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# import data set

# %%
data = pd.read_csv('Lesson_4_student_grades_dataset.csv', encoding = "latin-1")
data.head()
# Out:
#    Hours_of_Study  Attendance_Percentage  Previous_Exam_Scores  \
# 0        4.370861              75.553988             63.085284
# 1        9.556429              86.257028             62.348940
# 2        7.587945              96.188375             95.312729
# 3        6.387926              91.966747             62.477310
# 4        2.404168              94.196834             63.597486
#
#    Extracurricular_Activities  Travel_Time_to_School     Grades
# 0                           0              24.325977  31.494329
# 1                           0              50.132016  43.250150
# 2                           0              59.861895  30.155663
# 3                           1              11.501300  39.617522
# 4                           0              54.868293  33.175874

# %% [markdown]
# preparing data for modeling

# %%
plt.scatter(data['Hours_of_Study'], data['Attendance_Percentage'], data['Previous_Exam_Scores'], data['Grades'])
plt.xlabel('Independent Variable')
plt.ylabel('Independent Variable')
plt.title('Effects of hours of study and attendance percentage in previous exam scores')
plt.show()

# %%
X = data.drop('Grades', axis=1)
Y = data[['Grades']]

# %% [markdown]
# split and fit

# %%
X_Hours_of_Study, X_Attendance_Percentage, X_Hours_of_Study, Y_Previous_Exam_Scores = train_test_split(X,Y, test_size=0.2, random_state=42)

model = LinearRegression()
model.fit (X_train,Y_train)
# Out:
# LinearRegression()

# %% [markdown]
# making predictions

# %%
slope = model.coef_[0]
intercept = model.intercept_
print('Slope', slope)
print('Intercept', intercept)
# Out:
# Slope [ 0.33491143  0.20253934  0.25216937  4.87399857 -0.09033945]
# Intercept [-1.1380583]

# %%
new_data = np.array([[2,70,85,1,50]])
prediction = model.predict(new_data)
print(f"predict grades: {prediction[0]}")
# Out:
# predict grades: [35.50094091]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
report = """
Analysis report

1. Data loading and initial analysis:
   Basic statistics of a dataset:
   {}

2. Data manipulation:
   Effects of hours of study and attendance percentage on the final grade:
   {}

   Effects with the highest grades: {}
   Average effect per grade: {:.2f}

3. Data visualization:
   A scatter plot displaying grades for each grade is attached.

4. Insights:
   The product {} generates the highest revenue.
   On average, {:.2f} units are sold per day.
"""

Hours_of_Study =  "10 hours"
Attendance_Percentage = "Full attendance"
Previous_Exam_Scores = "Study hours"
Grades = 1

formatted_report = report.format(Hours_of_Study, Attendance_Percentage, Previous_Exam_Scores, Grades)
print(formatted_report)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-47-4de254234403> in <cell line: 28>()
#      26 Grades = 1
#      27
# ---> 28 formatted_report = report.format(Hours_of_Study, Attendance_Percentage, Previous_Exam_Scores, Grades)
#      29 print(formatted_report)
#      30
#
# IndexError: Replacement index 4 out of range for positional args tuple
