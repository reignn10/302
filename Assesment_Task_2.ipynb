# %% [markdown]
# <a href="https://colab.research.google.com/github/reignn10/CSEL/blob/main/Assesment_Task_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('hardwareStore.csv',encoding = "latin - 1")
data.head()
# Out:
#    ï»¿CATEGORY_ID CATEGORY_NAME  PRODUCT_ID           PRODUCT_NAME  \
# 0               1           CPU           8  Intel Xeon E5-1650 V4
# 1               1           CPU           8  Intel Xeon E5-1650 V4
# 2               1           CPU           8  Intel Xeon E5-1650 V4
# 3               1           CPU           8  Intel Xeon E5-1650 V4
# 4               1           CPU           8  Intel Xeon E5-1650 V4
#
#                      DESCRIPTION DESCRIPTION - Detail 1  \
# 0  Speed:3.6GHz,Cores:6,TDP:140W           Speed:3.6GHz
# 1  Speed:3.6GHz,Cores:6,TDP:140W           Speed:3.6GHz
# 2  Speed:3.6GHz,Cores:6,TDP:140W           Speed:3.6GHz
# 3  Speed:3.6GHz,Cores:6,TDP:140W           Speed:3.6GHz
# 4  Speed:3.6GHz,Cores:6,TDP:140W           Speed:3.6GHz
#
#   DESCRIPTION - Detail 2 DESCRIPTION - Detail 3 DESCRIPTION - Detail 4  \
# 0                Cores:6               TDP:140W                    NaN
# 1                Cores:6               TDP:140W                    NaN
# ...

# %%
(data.head())
(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1112 entries, 0 to 1111
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ï»¿CATEGORY_ID          1112 non-null   int64
#  1   CATEGORY_NAME           1112 non-null   object
#  2   PRODUCT_ID              1112 non-null   int64
#  3   PRODUCT_NAME            1112 non-null   object
#  4   DESCRIPTION             1112 non-null   object
#  5   DESCRIPTION - Detail 1  1112 non-null   object
#  6   DESCRIPTION - Detail 2  1112 non-null   object
#  7   DESCRIPTION - Detail 3  794 non-null    object
#  8   DESCRIPTION - Detail 4  350 non-null    object
#  9   STANDARD_COST           1112 non-null   float64
#  10  LIST_PRICE              1112 non-null   float64
#  11  COUNTRY_ID              1112 non-null   object
#  12  REGION_ID               1112 non-null   int64
#  13  LOCATION_ID             1112 non-null   int64
# ...

# %%
stats = data.describe()

# %%
df = pd.DataFrame({
    'REGION_ID': [3,3,2,2,3],
    'LOCATION_ID': [11,12,6,8,13]
})

df = pd.DataFrame(data)

# Check column names
print(df.region)

# Check DataFrame structure
print(df.head())

# Calculate total region for each location
total_region_per_location = df.groupby('Location')['Region'].sum()

# Display the result
print(total_region_per_location)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-bfa7d583926b> in <cell line: 9>()
#       7
#       8 # Check column names
# ----> 9 print(df.region)
#      10
#      11 # Check DataFrame structure
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
#    5904     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'region'

# %%
# @title REGION_ID vs LOCATION_ID

from matplotlib import pyplot as plt
df.plot(kind='scatter', x='REGION_ID', y='LOCATION_ID', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# Assuming you have defined and calculated the necessary variables before generating the report

# 1. Data loading and Initial Analysis
# Example: stats is a string containing basic statistics
stats = "Bassic statistics of the dataset"

# 2. Data Manipulation
# Example: location_region is a string containing the total region for each location
location_region = total_ordering_region_per_location.to_string()
# Example: hr_location is a string containing the location with the highest region
hr_location = "Your hr_location string here"
# Example: average_qty_per_day is a floating-point number containing the average quantity sold per day
average_qty_per_day = 42.17

# 3. Data Visualization
# Assuming you've attached a scatter plot as mentioned in the report

# 4. Insights
# Now you can generate the report
report = """
Analysis Report

1. Data loading and Initial Analysis:
Bassic statistics of the dataset;
{}

2. Data Manipulation:
Total region for each location:
{}
Location with the highest region; {}
Average quantity sold per day: {:.2f}

3. Data Visualization
Scatter char displaying region for each location i attached

4. Insights:
The location {} generates the highest region.
On average, {:.2f} units are sold per day.
""".format(stats, location_region, hr_location, average_qty_per_day, hr_location, average_qty_per_day)

# Print the report
print(report)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-14599b2e8ec2> in <cell line: 9>()
#       7 # 2. Data Manipulation
#       8 # Example: location_region is a string containing the total region for each location
# ----> 9 location_region = total_ordering_region_per_location.to_string()
#      10 # Example: hr_location is a string containing the location with the highest region
#      11 hr_location = "Your hr_location string here"
#
# NameError: name 'total_ordering_region_per_location' is not defined
